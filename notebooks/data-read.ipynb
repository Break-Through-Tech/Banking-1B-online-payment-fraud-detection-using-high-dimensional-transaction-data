# %%
import sys
from pathlib import Path

repo_root = Path.cwd().resolve()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from kaggle_auth import get_kaggle_credentials
import kagglehub

creds = get_kaggle_credentials()
print(creds)
# Out:
# {'username': 'salamotfakoya', 'key': 'KGAT_59aaddca15b7a87092bb2c4224b0a346'}

# %%
from kaggle_auth import get_kaggle_credentials
import kagglehub

creds = get_kaggle_credentials()
kagglehub.login()

# %%
import kagglehub

path = kagglehub.competition_download('ieee-fraud-detection')
print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 118M/118M [00:02<00:00, 50.2MB/s]
# Extracting files...
# Path to competition files: /home/codespace/.cache/kagglehub/competitions/ieee-fraud-detection

# %%
print("Path to competition files:", path)
# Out:
# Path to competition files: /home/codespace/.cache/kagglehub/competitions/ieee-fraud-detection

# %%
path
# Out:
# '/home/codespace/.cache/kagglehub/competitions/ieee-fraud-detection'

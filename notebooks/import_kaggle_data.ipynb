# %%
import kagglehub
kagglehub.login()  # will prompt you for your API token right here in the notebook
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
path = kagglehub.competition_download('ieee-fraud-detection')
print("Path to competition files:", path)
# Out:
# ...
# 100%|██████████| 118M/118M [00:01<00:00, 95.8MB/s]
# Extracting files...
# Path to competition files: /root/.cache/kagglehub/competitions/ieee-fraud-detection

# %%
import pandas as pd

sample_submission = pd.read_csv(''.join([path, "/", 'sample_submission.csv']))
test_identity = pd.read_csv(''.join([path, "/", "test_identity.csv"]))
test_transaction = pd.read_csv(''.join([path, "/", 'test_transaction.csv']))
train_identity = pd.read_csv(''.join([path, "/", 'train_identity.csv']))
train_transaction = pd.read_csv(''.join([path, "/", 'train_transaction.csv']))

# %%
sample_submission.head()
# Out:
#    TransactionID  isFraud
# 0        3663549      0.5
# 1        3663550      0.5
# 2        3663551      0.5
# 3        3663552      0.5
# 4        3663553      0.5
